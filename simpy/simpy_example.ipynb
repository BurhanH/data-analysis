# %%
# Today I found a framework for process-based discrete-event simulation 
# and tried to execite an example 
# (soure code from https://simpy.readthedocs.io/en/latest/examples/gas_station_refuel.html)

# %%
# Python 3.7.*, simpy 3.0.11

"""
Gas Station Refueling example

Covers:

- Resources: Resource
- Resources: Container
- Waiting for other processes

Scenario:
  A gas station has a limited number of gas pumps that share a common
  fuel reservoir. Cars randomly arrive at the gas station, request one
  of the fuel pumps and start refueling from that reservoir.

  A gas station control process observes the gas station's fuel level
  and calls a tank truck for refueling if the station's level drops
  below a threshold.

"""

import itertools
import random

import simpy


RANDOM_SEED = 42
GAS_STATION_SIZE = 200     # Liters
THRESHOLD = 20             # Threshold for calling the tank truck (in %)
FUEL_TANK_SIZE = 50        # Liters
FUEL_TANK_LEVEL = [5, 25]  # Min/max levels of fuel tanks (in liters)
REFUELING_SPEED = 2        # liters / second
TANK_TRUCK_TIME = 300      # Seconds it takes the tank truck to arrive
T_INTER = [30, 300]        # Create a car every [min, max] seconds
SIM_TIME = 100000           # Simulation time in seconds


def car(name: str,
        env_: simpy.Environment,
        gas_station_: simpy.Resource,
        fuel_pump_: simpy.Container) -> None:
    """A car arrives at the gas station for refueling.

    It requests one of the gas station's fuel pumps and tries to get the
    desired amount of gas from it. If the stations reservoir is
    depleted, the car has to wait for the tank truck to arrive.

    """
    fuel_tank_level = random.randint(*FUEL_TANK_LEVEL)
    print(f'{name} arriving at gas station at {env_.now}')
    with gas_station_.request() as req:
        start = env_.now
        # Request one of the gas pumps
        yield req

        # Get the required amount of fuel
        liters_required = FUEL_TANK_SIZE - fuel_tank_level
        yield fuel_pump_.get(liters_required)

        # The "actual" refueling process takes some time
        yield env_.timeout(liters_required / REFUELING_SPEED)

        print(f'{name} finished refueling in {env_.now - start} seconds.')


def gas_station_control(env_: simpy.Environment,
                        fuel_pump_: simpy.Container) -> None:
    """Periodically check the level of the *fuel_pump* and call the tank
    truck if the level falls below a threshold."""

    while True:
        if fuel_pump_.level / fuel_pump_.capacity * 100 < THRESHOLD:
            # We need to call the tank truck now!
            print(f'Calling tank truck at {env_.now}')
            # Wait for the tank truck to arrive and refuel the station
            yield env_.process(tank_truck(env_, fuel_pump_))

        yield env.timeout(10)  # Check every 10 seconds


def tank_truck(env_: simpy.Environment,
               fuel_pump_: simpy.Container) -> None:
    """Arrives at the gas station after a certain delay and refuels it."""

    yield env_.timeout(TANK_TRUCK_TIME)
    print(f'Tank truck arriving at time {env_.now}')
    amount = fuel_pump_.capacity - fuel_pump_.level
    print(f'Tank truck refuelling {amount} liters.')
    yield fuel_pump_.put(amount)


def car_generator(env_: simpy.Environment,
                  gas_station_: simpy.Resource,
                  fuel_pump_: simpy.Container) -> None:
    """Generate new cars that arrive at the gas station."""

    for i in itertools.count():
        yield env_.timeout(random.randint(*T_INTER))
        env_.process(car(f'Car {i}', env_, gas_station_, fuel_pump_))


# Setup and start the simulation
print('Gas Station refuelling')
random.seed(RANDOM_SEED)

# Create environment and start processes
env = simpy.Environment()
gas_station = simpy.Resource(env, 2)
fuel_pump = simpy.Container(env, GAS_STATION_SIZE, init=GAS_STATION_SIZE)
env.process(gas_station_control(env, fuel_pump))
env.process(car_generator(env, gas_station, fuel_pump))

# Execute!
env.run(until=SIM_TIME)
# Out:
# Gas Station refuelling
# Car 0 arriving at gas station at 87
# Car 0 finished refueling in 18.5 seconds.
# Car 1 arriving at gas station at 129
# Car 1 finished refueling in 19.0 seconds.
# Car 2 arriving at gas station at 284
# Car 2 finished refueling in 21.0 seconds.
# Car 3 arriving at gas station at 385
# Car 3 finished refueling in 13.5 seconds.
# Car 4 arriving at gas station at 459
# Calling tank truck at 460
# Car 4 finished refueling in 22.0 seconds.
# Car 5 arriving at gas station at 705
# Car 6 arriving at gas station at 750
# Tank truck arriving at time 760
# Tank truck refuelling 188 liters.
# Car 6 finished refueling in 29.0 seconds.
# Car 5 finished refueling in 76.5 seconds.
# Car 7 arriving at gas station at 891
# Car 7 finished refueling in 13.0 seconds.
# Car 8 arriving at gas station at 1179
# Car 8 finished refueling in 14.0 seconds.
# Car 9 arriving at gas station at 1222
# Car 9 finished refueling in 12.5 seconds.
# Car 10 arriving at gas station at 1353
# Calling tank truck at 1360
# Car 10 finished refueling in 19.0 seconds.
# Car 11 arriving at gas station at 1597
# Tank truck arriving at time 1660
# Tank truck refuelling 198 liters.
# Car 11 finished refueling in 76.5 seconds.
# Car 12 arriving at gas station at 1856
# Car 12 finished refueling in 22.5 seconds.
# Car 13 arriving at gas station at 2028
# Car 13 finished refueling in 16.0 seconds.
# Car 14 arriving at gas station at 2139
# Car 14 finished refueling in 18.5 seconds.
# Car 15 arriving at gas station at 2343
# Calling tank truck at 2350
# Car 15 finished refueling in 19.5 seconds.
# Car 16 arriving at gas station at 2452
# Tank truck arriving at time 2650
# Tank truck refuelling 180 liters.
# Car 17 arriving at gas station at 2654
# Car 17 finished refueling in 16.5 seconds.
# Car 16 finished refueling in 219.0 seconds.
# Car 18 arriving at gas station at 2731
# Car 18 finished refueling in 17.0 seconds.
# Car 19 arriving at gas station at 2810
# Car 19 finished refueling in 13.0 seconds.
# Car 20 arriving at gas station at 3016
# Calling tank truck at 3020
# Car 20 finished refueling in 22.0 seconds.
# Car 21 arriving at gas station at 3181
# Tank truck arriving at time 3320
# Tank truck refuelling 179 liters.
# Car 21 finished refueling in 153.0 seconds.
# Car 22 arriving at gas station at 3446
# Car 22 finished refueling in 16.5 seconds.
# Car 23 arriving at gas station at 3539
# Car 23 finished refueling in 14.0 seconds.
# Car 24 arriving at gas station at 3609
# Car 24 finished refueling in 12.5 seconds.
# Car 25 arriving at gas station at 3789
# Car 25 finished refueling in 13.5 seconds.
# Car 26 arriving at gas station at 4004
# Calling tank truck at 4010
# Car 26 finished refueling in 21.5 seconds.
# Car 27 arriving at gas station at 4132
# Car 28 arriving at gas station at 4185
# Tank truck arriving at time 4310
# Tank truck refuelling 184 liters.
# Car 27 finished refueling in 197.0 seconds.
# Car 28 finished refueling in 146.5 seconds.
# Car 29 arriving at gas station at 4363
# Car 29 finished refueling in 21.0 seconds.
# Car 30 arriving at gas station at 4512
# Car 30 finished refueling in 18.5 seconds.
# Car 31 arriving at gas station at 4736
# Calling tank truck at 4740
# Car 31 finished refueling in 12.5 seconds.
# Car 32 arriving at gas station at 4998
# Tank truck arriving at time 5040
# Tank truck refuelling 185 liters.
# Car 32 finished refueling in 62.0 seconds.
# Car 33 arriving at gas station at 5214
# Car 33 finished refueling in 17.0 seconds.
# Car 34 arriving at gas station at 5433
# Car 34 finished refueling in 18.5 seconds.
# Car 35 arriving at gas station at 5570
# Car 35 finished refueling in 13.0 seconds.
# Car 36 arriving at gas station at 5636
# Calling tank truck at 5640
# Car 36 finished refueling in 14.0 seconds.
# Car 37 arriving at gas station at 5753
# Car 38 arriving at gas station at 5908
# Tank truck arriving at time 5940
# Tank truck refuelling 165 liters.
# Car 38 finished refueling in 48.5 seconds.
# Car 37 finished refueling in 207.0 seconds.
# Car 39 arriving at gas station at 6174
# Car 39 finished refueling in 12.5 seconds.
# Car 40 arriving at gas station at 6342
# Car 40 finished refueling in 17.5 seconds.
# Car 41 arriving at gas station at 6484
# Calling tank truck at 6490
# Car 41 finished refueling in 19.0 seconds.
# Car 42 arriving at gas station at 6542
# Car 43 arriving at gas station at 6588
# Tank truck arriving at time 6790
# Tank truck refuelling 171 liters.
# Car 42 finished refueling in 265.5 seconds.
# Car 43 finished refueling in 220.5 seconds.
# Car 44 arriving at gas station at 6823
# Car 44 finished refueling in 19.5 seconds.
# Car 45 arriving at gas station at 6886
# Car 45 finished refueling in 19.5 seconds.
# Car 46 arriving at gas station at 7077
# Calling tank truck at 7080
# Car 46 finished refueling in 16.5 seconds.
# Car 47 arriving at gas station at 7362
# Tank truck arriving at time 7380
# Tank truck refuelling 183 liters.
# Car 47 finished refueling in 38.5 seconds.
# Car 48 arriving at gas station at 7626
# Car 48 finished refueling in 20.5 seconds.
# Car 49 arriving at gas station at 7791
# Car 49 finished refueling in 14.0 seconds.
# Car 50 arriving at gas station at 7947
# Car 50 finished refueling in 13.5 seconds.
# Car 51 arriving at gas station at 8111
# Calling tank truck at 8120
# Car 51 finished refueling in 13.5 seconds.
# Car 52 arriving at gas station at 8360
# Car 52 finished refueling in 17.0 seconds.
# Tank truck arriving at time 8420
# Tank truck refuelling 198 liters.
# Car 53 arriving at gas station at 8594
# Car 53 finished refueling in 20.5 seconds.
# Car 54 arriving at gas station at 8736
# Car 54 finished refueling in 15.0 seconds.
# Car 55 arriving at gas station at 9026
# Car 55 finished refueling in 22.0 seconds.
# Car 56 arriving at gas station at 9102
# Car 56 finished refueling in 20.5 seconds.
# Car 57 arriving at gas station at 9188
# Calling tank truck at 9190
# Car 57 finished refueling in 16.0 seconds.
# Car 58 arriving at gas station at 9299
# Car 59 arriving at gas station at 9361
# Tank truck arriving at time 9490
# Tank truck refuelling 188 liters.
# Car 59 finished refueling in 142.0 seconds.
# Car 58 finished refueling in 207.5 seconds.
# Car 60 arriving at gas station at 9586
# Car 60 finished refueling in 14.5 seconds.
# Car 61 arriving at gas station at 9855
# Car 61 finished refueling in 14.0 seconds.
# Car 62 arriving at gas station at 10013
# Car 62 finished refueling in 21.0 seconds.
# Car 63 arriving at gas station at 10048
# Calling tank truck at 10050
# Car 63 finished refueling in 12.5 seconds.
# Car 64 arriving at gas station at 10214
# Tank truck arriving at time 10350
# Tank truck refuelling 183 liters.
# Car 64 finished refueling in 157.0 seconds.
# Car 65 arriving at gas station at 10418
# Car 65 finished refueling in 16.0 seconds.
# Car 66 arriving at gas station at 10598
# Car 66 finished refueling in 15.5 seconds.
# Car 67 arriving at gas station at 10708
# Car 67 finished refueling in 18.5 seconds.
# Car 68 arriving at gas station at 10739
# Calling tank truck at 10740
# Car 68 finished refueling in 20.0 seconds.
# Car 69 arriving at gas station at 11025
# Tank truck arriving at time 11040
# Tank truck refuelling 182 liters.
# Car 69 finished refueling in 36.0 seconds.
# Car 70 arriving at gas station at 11314
# Car 70 finished refueling in 12.5 seconds.
# Car 71 arriving at gas station at 11496
# Car 71 finished refueling in 13.0 seconds.
# Car 72 arriving at gas station at 11785
# Car 72 finished refueling in 20.5 seconds.
# Car 73 arriving at gas station at 11916
# Calling tank truck at 11920
# Car 73 finished refueling in 20.0 seconds.
# Car 74 arriving at gas station at 12137
# Car 74 finished refueling in 13.0 seconds.
# Car 75 arriving at gas station at 12167
# Tank truck arriving at time 12220
# Tank truck refuelling 200 liters.
# Car 75 finished refueling in 68.0 seconds.
# Car 76 arriving at gas station at 12362
# Car 76 finished refueling in 21.0 seconds.
# Car 77 arriving at gas station at 12401
# Car 77 finished refueling in 18.0 seconds.
# Car 78 arriving at gas station at 12616
# Car 78 finished refueling in 22.0 seconds.
# Car 79 arriving at gas station at 12768
# Calling tank truck at 12770
# Car 79 finished refueling in 13.5 seconds.
# Car 80 arriving at gas station at 12921
# Car 81 arriving at gas station at 12991
# Tank truck arriving at time 13070
# Tank truck refuelling 179 liters.
# Car 80 finished refueling in 170.5 seconds.
# Car 81 finished refueling in 100.5 seconds.
# Car 82 arriving at gas station at 13269
# Car 82 finished refueling in 20.5 seconds.
# Car 83 arriving at gas station at 13363
# Car 83 finished refueling in 14.0 seconds.
# Car 84 arriving at gas station at 13636
# Calling tank truck at 13640
# Car 84 finished refueling in 18.5 seconds.
# Car 85 arriving at gas station at 13750
# Tank truck arriving at time 13940
# Tank truck refuelling 192 liters.
# Car 85 finished refueling in 203.0 seconds.
# Car 86 arriving at gas station at 14050
# Car 86 finished refueling in 19.5 seconds.
# Car 87 arriving at gas station at 14296
# Car 87 finished refueling in 18.0 seconds.
# Car 88 arriving at gas station at 14428
# Car 88 finished refueling in 12.5 seconds.
# Car 89 arriving at gas station at 14662
# Car 89 finished refueling in 15.5 seconds.
# Car 90 arriving at gas station at 14883
# Calling tank truck at 14890
# Car 90 finished refueling in 15.5 seconds.
# Car 91 arriving at gas station at 15177
# Tank truck arriving at time 15190
# Tank truck refuelling 188 liters.
# Car 91 finished refueling in 32.0 seconds.
# Car 92 arriving at gas station at 15268
# Car 92 finished refueling in 21.5 seconds.
# Car 93 arriving at gas station at 15413
# Car 93 finished refueling in 22.5 seconds.
# Car 94 arriving at gas station at 15616
# Car 94 finished refueling in 13.5 seconds.
# Car 95 arriving at gas station at 15763
# Calling tank truck at 15770
# Car 95 finished refueling in 22.5 seconds.
# Car 96 arriving at gas station at 15905
# Car 97 arriving at gas station at 15971
# Car 98 arriving at gas station at 16031
# Tank truck arriving at time 16070
# Tank truck refuelling 198 liters.
# Car 96 finished refueling in 177.5 seconds.
# Car 97 finished refueling in 118.0 seconds.
# Car 99 arriving at gas station at 16095
# Car 98 finished refueling in 73.5 seconds.
# Car 99 finished refueling in 21.5 seconds.
# Car 100 arriving at gas station at 16294
# Calling tank truck at 16300
# Car 100 finished refueling in 19.0 seconds.
# Car 101 arriving at gas station at 16587
# Tank truck arriving at time 16600
# Tank truck refuelling 188 liters.
# Car 101 finished refueling in 28.0 seconds.
# Car 102 arriving at gas station at 16759
# Car 102 finished refueling in 14.0 seconds.
# Car 103 arriving at gas station at 16898
# Car 103 finished refueling in 13.5 seconds.
# Car 104 arriving at gas station at 16995
# Car 104 finished refueling in 19.0 seconds.
# Car 105 arriving at gas station at 17267
# Car 105 finished refueling in 16.0 seconds.
# Car 106 arriving at gas station at 17539
# Calling tank truck at 17540
# Car 106 finished refueling in 21.0 seconds.
# Car 107 arriving at gas station at 17666
# Car 108 arriving at gas station at 17745
# Tank truck arriving at time 17840
# Tank truck refuelling 197 liters.
# Car 107 finished refueling in 190.0 seconds.
# Car 108 finished refueling in 111.0 seconds.
# Car 109 arriving at gas station at 17956
# Car 109 finished refueling in 15.5 seconds.
# Car 110 arriving at gas station at 18196
# Car 110 finished refueling in 12.5 seconds.
# Car 111 arriving at gas station at 18253
# Calling tank truck at 18260
# Car 111 finished refueling in 22.0 seconds.
# Car 112 arriving at gas station at 18333
# Car 112 finished refueling in 17.5 seconds.
# Tank truck arriving at time 18560
# Tank truck refuelling 199 liters.
# Car 113 arriving at gas station at 18569
# Car 113 finished refueling in 19.0 seconds.
# Car 114 arriving at gas station at 18654
# Car 114 finished refueling in 19.5 seconds.
# Car 115 arriving at gas station at 18782
# Car 115 finished refueling in 20.5 seconds.
# Car 116 arriving at gas station at 19041
# Car 116 finished refueling in 20.0 seconds.
# Car 117 arriving at gas station at 19287
# Calling tank truck at 19290
# Car 117 finished refueling in 15.5 seconds.
# Car 118 arriving at gas station at 19459
# Tank truck arriving at time 19590
# Tank truck refuelling 189 liters.
# Car 118 finished refueling in 152.5 seconds.
# Car 119 arriving at gas station at 19616
# Car 119 finished refueling in 14.0 seconds.
# Car 120 arriving at gas station at 19872
# Car 120 finished refueling in 22.0 seconds.
# Car 121 arriving at gas station at 19952
# Car 121 finished refueling in 21.5 seconds.
# Car 122 arriving at gas station at 19989
# Calling tank truck at 19990
# Car 122 finished refueling in 20.0 seconds.
# Car 123 arriving at gas station at 20140
# Tank truck arriving at time 20290
# Tank truck refuelling 198 liters.
# Car 123 finished refueling in 165.0 seconds.
# Car 124 arriving at gas station at 20378
# Car 124 finished refueling in 19.5 seconds.
# Car 125 arriving at gas station at 20654
# Car 125 finished refueling in 22.0 seconds.
# Car 126 arriving at gas station at 20889
# Car 126 finished refueling in 16.5 seconds.
# Car 127 arriving at gas station at 21003
# Calling tank truck at 21010
# Car 127 finished refueling in 16.5 seconds.
# Car 128 arriving at gas station at 21034
# Car 129 arriving at gas station at 21199
# Tank truck arriving at time 21310
# Tank truck refuelling 179 liters.
# Car 128 finished refueling in 291.5 seconds.
# Car 129 finished refueling in 127.0 seconds.
# Car 130 arriving at gas station at 21375
# Car 130 finished refueling in 20.5 seconds.
# Car 131 arriving at gas station at 21654
# Car 131 finished refueling in 18.0 seconds.
# Car 132 arriving at gas station at 21781
# Calling tank truck at 21790
# Car 132 finished refueling in 22.0 seconds.
# Car 133 arriving at gas station at 21922
# Car 134 arriving at gas station at 21983
# Car 135 arriving at gas station at 22042
# Tank truck arriving at time 22090
# Tank truck refuelling 184 liters.
# Car 133 finished refueling in 185.5 seconds.
# Car 134 finished refueling in 129.0 seconds.
# Car 135 finished refueling in 80.0 seconds.
# Car 136 arriving at gas station at 22316
# Car 136 finished refueling in 22.0 seconds.
# Car 137 arriving at gas station at 22426
# Calling tank truck at 22430
# Car 137 finished refueling in 21.5 seconds.
# Car 138 arriving at gas station at 22716
# Tank truck arriving at time 22730
# Tank truck refuelling 195 liters.
# Car 138 finished refueling in 35.5 seconds.
# Car 139 arriving at gas station at 22841
# Car 139 finished refueling in 19.0 seconds.
# Car 140 arriving at gas station at 22905
# Car 140 finished refueling in 21.0 seconds.
# Car 141 arriving at gas station at 23141
# Car 141 finished refueling in 13.5 seconds.
# Car 142 arriving at gas station at 23297
# Calling tank truck at 23300
# Car 142 finished refueling in 13.0 seconds.
# Car 143 arriving at gas station at 23347
# Car 144 arriving at gas station at 23418
# Tank truck arriving at time 23600
# Tank truck refuelling 176 liters.
# Car 143 finished refueling in 269.0 seconds.
# Car 144 finished refueling in 199.5 seconds.
# Car 145 arriving at gas station at 23715
# Car 145 finished refueling in 19.5 seconds.
# Car 146 arriving at gas station at 23878
# Car 146 finished refueling in 19.0 seconds.
# Car 147 arriving at gas station at 24068
# Calling tank truck at 24070
# Car 147 finished refueling in 16.5 seconds.
# Car 148 arriving at gas station at 24233
# Car 149 arriving at gas station at 24330
# Tank truck arriving at time 24370
# Tank truck refuelling 177 liters.
# Car 148 finished refueling in 149.5 seconds.
# Car 149 finished refueling in 55.5 seconds.
# Car 150 arriving at gas station at 24513
# Car 150 finished refueling in 21.5 seconds.
# Car 151 arriving at gas station at 24704
# Car 151 finished refueling in 15.5 seconds.
# Car 152 arriving at gas station at 24738
# Calling tank truck at 24740
# Car 152 finished refueling in 21.5 seconds.
# Car 153 arriving at gas station at 24819
# Car 154 arriving at gas station at 24958
# Tank truck arriving at time 25040
# Tank truck refuelling 173 liters.
# Car 153 finished refueling in 235.5 seconds.
# Car 154 finished refueling in 102.5 seconds.
# Car 155 arriving at gas station at 25123
# Car 155 finished refueling in 21.5 seconds.
# Car 156 arriving at gas station at 25331
# Car 156 finished refueling in 17.0 seconds.
# Car 157 arriving at gas station at 25486
# Calling tank truck at 25490
# Car 157 finished refueling in 20.0 seconds.
# Car 158 arriving at gas station at 25661
# Tank truck arriving at time 25790
# Tank truck refuelling 187 liters.
# Car 158 finished refueling in 143.0 seconds.
# Car 159 arriving at gas station at 25915
# Car 159 finished refueling in 13.0 seconds.
# Car 160 arriving at gas station at 26099
# Car 160 finished refueling in 22.5 seconds.
# Car 161 arriving at gas station at 26399
# Car 161 finished refueling in 21.0 seconds.
# Car 162 arriving at gas station at 26582
# Calling tank truck at 26590
# Car 162 finished refueling in 18.5 seconds.
# Car 163 arriving at gas station at 26680
# Car 164 arriving at gas station at 26769
# Car 165 arriving at gas station at 26878
# Tank truck arriving at time 26890
# Tank truck refuelling 178 liters.
# Car 164 finished refueling in 139.5 seconds.
# Car 163 finished refueling in 231.0 seconds.
# Car 165 finished refueling in 43.5 seconds.
# Car 166 arriving at gas station at 27052
# Car 166 finished refueling in 17.5 seconds.
# Car 167 arriving at gas station at 27189
# Calling tank truck at 27190
# Car 167 finished refueling in 12.5 seconds.
# Car 168 arriving at gas station at 27323
# Car 168 finished refueling in 14.5 seconds.
# Car 169 arriving at gas station at 27488
# Tank truck arriving at time 27490
# Tank truck refuelling 194 liters.
# Car 169 finished refueling in 20.5 seconds.
# Car 170 arriving at gas station at 27768
# Car 170 finished refueling in 21.5 seconds.
# Car 171 arriving at gas station at 27824
# Car 171 finished refueling in 18.5 seconds.
# Car 172 arriving at gas station at 28070
# Calling tank truck at 28080
# Car 172 finished refueling in 22.5 seconds.
# Car 173 arriving at gas station at 28122
# Car 174 arriving at gas station at 28322
# Tank truck arriving at time 28380
# Tank truck refuelling 162 liters.
# Car 174 finished refueling in 78.0 seconds.
# Car 173 finished refueling in 278.5 seconds.
# Car 175 arriving at gas station at 28486
# Car 175 finished refueling in 14.0 seconds.
# Car 176 arriving at gas station at 28742
# Car 176 finished refueling in 14.0 seconds.
# Car 177 arriving at gas station at 28990
# Calling tank truck at 29000
# Car 177 finished refueling in 21.0 seconds.
# Car 178 arriving at gas station at 29024
# Car 179 arriving at gas station at 29092
# Car 180 arriving at gas station at 29140
# Car 181 arriving at gas station at 29245
# Tank truck arriving at time 29300
# Tank truck refuelling 179 liters.
# Car 179 finished refueling in 225.0 seconds.
# Car 178 finished refueling in 296.5 seconds.
# Car 180 finished refueling in 193.0 seconds.
# Car 182 arriving at gas station at 29340
# Car 181 finished refueling in 97.5 seconds.
# Calling tank truck at 29350
# Car 182 finished refueling in 17.0 seconds.
# Car 183 arriving at gas station at 29527
# Car 184 arriving at gas station at 29577
# Tank truck arriving at time 29650
# Tank truck refuelling 185 liters.
# Car 183 finished refueling in 140.0 seconds.
# Car 184 finished refueling in 92.0 seconds.
# Car 185 arriving at gas station at 29714
# Car 185 finished refueling in 17.0 seconds.
# Car 186 arriving at gas station at 29796
# Car 186 finished refueling in 13.0 seconds.
# Car 187 arriving at gas station at 30034
# Calling tank truck at 30040
# Car 187 finished refueling in 19.0 seconds.
# Car 188 arriving at gas station at 30143
# Car 189 arriving at gas station at 30256
# Tank truck arriving at time 30340
# Tank truck refuelling 170 liters.
# Car 188 finished refueling in 217.0 seconds.
# Car 189 finished refueling in 106.5 seconds.
# Car 190 arriving at gas station at 30497
# Car 190 finished refueling in 17.5 seconds.
# Car 191 arriving at gas station at 30618
# Car 191 finished refueling in 19.0 seconds.
# Car 192 arriving at gas station at 30858
# Calling tank truck at 30860
# Car 192 finished refueling in 20.0 seconds.
# Car 193 arriving at gas station at 31024
# Car 194 arriving at gas station at 31109
# Car 195 arriving at gas station at 31158
# Tank truck arriving at time 31160
# Tank truck refuelling 198 liters.
# Car 194 finished refueling in 66.0 seconds.
# Car 193 finished refueling in 152.5 seconds.
# Car 195 finished refueling in 36.5 seconds.
# Car 196 arriving at gas station at 31301
# Car 196 finished refueling in 17.0 seconds.
# Car 197 arriving at gas station at 31566
# Calling tank truck at 31570
# Car 197 finished refueling in 19.0 seconds.
# Car 198 arriving at gas station at 31752
# Tank truck arriving at time 31870
# Tank truck refuelling 174 liters.
# Car 198 finished refueling in 140.5 seconds.
# Car 199 arriving at gas station at 31896
# Car 199 finished refueling in 16.5 seconds.
# Car 200 arriving at gas station at 32024
# Car 200 finished refueling in 18.5 seconds.
# Car 201 arriving at gas station at 32222
# Car 201 finished refueling in 18.5 seconds.
# Car 202 arriving at gas station at 32287
# Calling tank truck at 32290
# Car 202 finished refueling in 12.5 seconds.
# Car 203 arriving at gas station at 32496
# Tank truck arriving at time 32590
# Tank truck refuelling 177 liters.
# Car 203 finished refueling in 110.5 seconds.
# Car 204 arriving at gas station at 32786
# Car 204 finished refueling in 22.5 seconds.
# Car 205 arriving at gas station at 32985
# Car 205 finished refueling in 18.5 seconds.
# Car 206 arriving at gas station at 33074
# Car 206 finished refueling in 13.5 seconds.
# Car 207 arriving at gas station at 33195
# Calling tank truck at 33200
# Car 207 finished refueling in 22.0 seconds.
# Car 208 arriving at gas station at 33360
# Car 209 arriving at gas station at 33445
# Tank truck arriving at time 33500
# Tank truck refuelling 186 liters.
# Car 208 finished refueling in 153.0 seconds.
# Car 209 finished refueling in 72.0 seconds.
# Car 210 arriving at gas station at 33697
# Car 210 finished refueling in 16.0 seconds.
# Car 211 arriving at gas station at 33887
# Car 211 finished refueling in 21.0 seconds.
# Car 212 arriving at gas station at 34178
# Calling tank truck at 34180
# Car 212 finished refueling in 13.5 seconds.
# Car 213 arriving at gas station at 34405
# Car 213 finished refueling in 18.5 seconds.
# Tank truck arriving at time 34480
# Tank truck refuelling 198 liters.
# Car 214 arriving at gas station at 34532
# Car 214 finished refueling in 16.0 seconds.
# Car 215 arriving at gas station at 34584
# Car 215 finished refueling in 14.5 seconds.
# Car 216 arriving at gas station at 34614
# Car 216 finished refueling in 17.0 seconds.
# Car 217 arriving at gas station at 34744
# Car 217 finished refueling in 21.5 seconds.
# Car 218 arriving at gas station at 34994
# Calling tank truck at 35000
# Car 218 finished refueling in 13.0 seconds.
# Car 219 arriving at gas station at 35193
# Tank truck arriving at time 35300
# Tank truck refuelling 164 liters.
# Car 219 finished refueling in 128.0 seconds.
# Car 220 arriving at gas station at 35383
# Car 220 finished refueling in 14.5 seconds.
# Car 221 arriving at gas station at 35566
# Car 221 finished refueling in 16.0 seconds.
# Car 222 arriving at gas station at 35754
# Car 222 finished refueling in 16.5 seconds.
# Car 223 arriving at gas station at 35951
# Calling tank truck at 35960
# Car 223 finished refueling in 14.0 seconds.
# Car 224 arriving at gas station at 36132
# Car 225 arriving at gas station at 36227
# Tank truck arriving at time 36260
# Tank truck refuelling 164 liters.
# Car 225 finished refueling in 49.5 seconds.
# Car 224 finished refueling in 147.5 seconds.
# Car 226 arriving at gas station at 36472
# Car 226 finished refueling in 13.0 seconds.
# Car 227 arriving at gas station at 36591
# Car 227 finished refueling in 16.5 seconds.
# Car 228 arriving at gas station at 36775
# Calling tank truck at 36780
# Car 228 finished refueling in 18.0 seconds.
# Car 229 arriving at gas station at 36805
# Car 230 arriving at gas station at 36981
# Tank truck arriving at time 37080
# Tank truck refuelling 167 liters.
# Car 230 finished refueling in 112.5 seconds.
# Car 229 finished refueling in 294.5 seconds.
# Car 231 arriving at gas station at 37231
# Car 231 finished refueling in 15.5 seconds.
# Car 232 arriving at gas station at 37425
# Car 232 finished refueling in 15.5 seconds.
# Car 233 arriving at gas station at 37681
# Car 233 finished refueling in 14.5 seconds.
# Car 234 arriving at gas station at 37820
# Calling tank truck at 37830
# Car 234 finished refueling in 20.0 seconds.
# Car 235 arriving at gas station at 38092
# Tank truck arriving at time 38130
# Tank truck refuelling 197 liters.
# Car 235 finished refueling in 56.0 seconds.
# Car 236 arriving at gas station at 38165
# Car 236 finished refueling in 12.5 seconds.
# Car 237 arriving at gas station at 38458
# Car 237 finished refueling in 21.5 seconds.
# Car 238 arriving at gas station at 38659
# Car 238 finished refueling in 18.0 seconds.
# Car 239 arriving at gas station at 38809
# Calling tank truck at 38810
# Car 239 finished refueling in 19.5 seconds.
# Car 240 arriving at gas station at 38954
# Car 241 arriving at gas station at 39059
# Tank truck arriving at time 39110
# Tank truck refuelling 179 liters.
# Car 242 arriving at gas station at 39112
# Car 241 finished refueling in 70.0 seconds.
# Car 240 finished refueling in 178.5 seconds.
# Car 242 finished refueling in 30.0 seconds.
# Car 243 arriving at gas station at 39385
# Car 243 finished refueling in 15.5 seconds.
# Car 244 arriving at gas station at 39452
# Calling tank truck at 39460
# Car 244 finished refueling in 12.5 seconds.
# Car 245 arriving at gas station at 39694
# Car 245 finished refueling in 16.5 seconds.
# Tank truck arriving at time 39760
# Tank truck refuelling 198 liters.
# Car 246 arriving at gas station at 39823
# Car 246 finished refueling in 16.5 seconds.
# Car 247 arriving at gas station at 40106
# Car 247 finished refueling in 20.5 seconds.
# Car 248 arriving at gas station at 40260
# Car 248 finished refueling in 21.0 seconds.
# Car 249 arriving at gas station at 40292
# Car 249 finished refueling in 19.0 seconds.
# Car 250 arriving at gas station at 40539
# Calling tank truck at 40540
# Car 250 finished refueling in 14.5 seconds.
# Car 251 arriving at gas station at 40659
# Tank truck arriving at time 40840
# Tank truck refuelling 183 liters.
# Car 251 finished refueling in 203.0 seconds.
# Car 252 arriving at gas station at 40926
# Car 252 finished refueling in 21.0 seconds.
# Car 253 arriving at gas station at 41083
# Car 253 finished refueling in 20.5 seconds.
# Car 254 arriving at gas station at 41346
# Car 254 finished refueling in 14.5 seconds.
# Car 255 arriving at gas station at 41613
# Calling tank truck at 41620
# Car 255 finished refueling in 15.5 seconds.
# Car 256 arriving at gas station at 41805
# Tank truck arriving at time 41920
# Tank truck refuelling 187 liters.
# Car 256 finished refueling in 131.0 seconds.
# Car 257 arriving at gas station at 42093
# Car 257 finished refueling in 20.0 seconds.
# Car 258 arriving at gas station at 42351
# Car 258 finished refueling in 15.5 seconds.
# Car 259 arriving at gas station at 42624
# Car 259 finished refueling in 19.0 seconds.
# Car 260 arriving at gas station at 42786
# Calling tank truck at 42790
# Car 260 finished refueling in 14.5 seconds.
# Car 261 arriving at gas station at 42957
# Car 261 finished refueling in 12.5 seconds.
# Tank truck arriving at time 43090
# Tank truck refuelling 195 liters.
# Car 262 arriving at gas station at 43235
# Car 262 finished refueling in 18.5 seconds.
# Car 263 arriving at gas station at 43387
# Car 263 finished refueling in 21.5 seconds.
# Car 264 arriving at gas station at 43642
# Car 264 finished refueling in 19.0 seconds.
# Car 265 arriving at gas station at 43818
# Car 265 finished refueling in 17.5 seconds.
# Car 266 arriving at gas station at 43987
# Calling tank truck at 43990
# Car 266 finished refueling in 14.0 seconds.
# Car 267 arriving at gas station at 44180
# Car 268 arriving at gas station at 44251
# Tank truck arriving at time 44290
# Tank truck refuelling 181 liters.
# Car 268 finished refueling in 58.0 seconds.
# Car 267 finished refueling in 130.5 seconds.
# Car 269 arriving at gas station at 44358
# Car 269 finished refueling in 20.5 seconds.
# Car 270 arriving at gas station at 44584
# Calling tank truck at 44590
# Car 270 finished refueling in 21.5 seconds.
# Car 271 arriving at gas station at 44723
# Car 271 finished refueling in 16.0 seconds.
# Tank truck arriving at time 44890
# Tank truck refuelling 195 liters.
# Car 272 arriving at gas station at 44965
# Car 272 finished refueling in 14.0 seconds.
# Car 273 arriving at gas station at 45164
# Car 273 finished refueling in 16.0 seconds.
# Car 274 arriving at gas station at 45432
# Car 274 finished refueling in 19.5 seconds.
# Car 275 arriving at gas station at 45493
# Car 275 finished refueling in 16.5 seconds.
# Car 276 arriving at gas station at 45738
# Car 276 finished refueling in 13.5 seconds.
# Car 277 arriving at gas station at 45778
# Calling tank truck at 45780
# Car 277 finished refueling in 15.0 seconds.
# Car 278 arriving at gas station at 46002
# Car 279 arriving at gas station at 46035
# Tank truck arriving at time 46080
# Tank truck refuelling 189 liters.
# Car 279 finished refueling in 61.5 seconds.
# Car 278 finished refueling in 95.0 seconds.
# Car 280 arriving at gas station at 46217
# Car 280 finished refueling in 14.0 seconds.
# Car 281 arriving at gas station at 46461
# Car 281 finished refueling in 15.0 seconds.
# Car 282 arriving at gas station at 46603
# Calling tank truck at 46610
# Car 282 finished refueling in 18.5 seconds.
# Car 283 arriving at gas station at 46745
# Car 283 finished refueling in 15.0 seconds.
# Tank truck arriving at time 46910
# Tank truck refuelling 192 liters.
# Car 284 arriving at gas station at 46998
# Car 284 finished refueling in 16.5 seconds.
# Car 285 arriving at gas station at 47042
# Car 285 finished refueling in 16.5 seconds.
# Car 286 arriving at gas station at 47244
# Car 286 finished refueling in 15.5 seconds.
# Car 287 arriving at gas station at 47358
# Car 287 finished refueling in 13.0 seconds.
# Car 288 arriving at gas station at 47453
# Car 288 finished refueling in 16.5 seconds.
# Car 289 arriving at gas station at 47496
# Calling tank truck at 47500
# Car 289 finished refueling in 21.5 seconds.
# Car 290 arriving at gas station at 47539
# Car 291 arriving at gas station at 47788
# Tank truck arriving at time 47800
# Tank truck refuelling 199 liters.
# Car 291 finished refueling in 32.0 seconds.
# Car 290 finished refueling in 281.5 seconds.
# Car 292 arriving at gas station at 48054
# Car 292 finished refueling in 18.5 seconds.
# Car 293 arriving at gas station at 48109
# Car 293 finished refueling in 17.5 seconds.
# Car 294 arriving at gas station at 48333
# Calling tank truck at 48340
# Car 294 finished refueling in 15.5 seconds.
# Car 295 arriving at gas station at 48471
# Tank truck arriving at time 48640
# Tank truck refuelling 184 liters.
# Car 295 finished refueling in 186.5 seconds.
# Car 296 arriving at gas station at 48668
# Car 296 finished refueling in 18.5 seconds.
# Car 297 arriving at gas station at 48892
# Car 297 finished refueling in 18.5 seconds.
# Car 298 arriving at gas station at 49137
# Car 298 finished refueling in 15.0 seconds.
# Car 299 arriving at gas station at 49208
# Calling tank truck at 49210
# Car 299 finished refueling in 14.0 seconds.
# Car 300 arriving at gas station at 49247
# Car 301 arriving at gas station at 49303
# Car 302 arriving at gas station at 49447
# Tank truck arriving at time 49510
# Tank truck refuelling 167 liters.
# Car 303 arriving at gas station at 49512
# Car 301 finished refueling in 219.5 seconds.
# Car 300 finished refueling in 280.0 seconds.
# Car 302 finished refueling in 88.0 seconds.
# Car 303 finished refueling in 37.5 seconds.
# Car 304 arriving at gas station at 49562
# Calling tank truck at 49570
# Car 304 finished refueling in 19.5 seconds.
# Car 305 arriving at gas station at 49718
# Car 305 finished refueling in 13.0 seconds.
# Car 306 arriving at gas station at 49758
# Car 307 arriving at gas station at 49866
# Tank truck arriving at time 49870
# Tank truck refuelling 194 liters.
# Car 307 finished refueling in 19.0 seconds.
# Car 306 finished refueling in 131.0 seconds.
# Car 308 arriving at gas station at 49960
# Car 308 finished refueling in 13.5 seconds.
# Car 309 arriving at gas station at 50048
# Car 309 finished refueling in 15.5 seconds.
# Car 310 arriving at gas station at 50189
# Car 310 finished refueling in 17.0 seconds.
# Car 311 arriving at gas station at 50350
# Calling tank truck at 50360
# Car 311 finished refueling in 13.0 seconds.
# Car 312 arriving at gas station at 50465
# Car 313 arriving at gas station at 50553
# Tank truck arriving at time 50660
# Tank truck refuelling 186 liters.
# Car 312 finished refueling in 215.0 seconds.
# Car 313 finished refueling in 128.0 seconds.
# Car 314 arriving at gas station at 50742
# Car 314 finished refueling in 18.0 seconds.
# Car 315 arriving at gas station at 50785
# Car 315 finished refueling in 16.5 seconds.
# Car 316 arriving at gas station at 51007
# Calling tank truck at 51010
# Car 316 finished refueling in 21.5 seconds.
# Car 317 arriving at gas station at 51138
# Car 318 arriving at gas station at 51292
# Tank truck arriving at time 51310
# Tank truck refuelling 194 liters.
# Car 318 finished refueling in 31.0 seconds.
# Car 317 finished refueling in 193.0 seconds.
# Car 319 arriving at gas station at 51476
# Car 319 finished refueling in 13.5 seconds.
# Car 320 arriving at gas station at 51567
# Car 320 finished refueling in 17.0 seconds.
# Car 321 arriving at gas station at 51618
# Calling tank truck at 51620
# Car 321 finished refueling in 17.0 seconds.
# Car 322 arriving at gas station at 51867
# Car 322 finished refueling in 14.5 seconds.
# Tank truck arriving at time 51920
# Tank truck refuelling 192 liters.
# Car 323 arriving at gas station at 51932
# Car 323 finished refueling in 22.5 seconds.
# Car 324 arriving at gas station at 52136
# Car 324 finished refueling in 15.0 seconds.
# Car 325 arriving at gas station at 52381
# Car 325 finished refueling in 16.0 seconds.
# Car 326 arriving at gas station at 52465
# Car 326 finished refueling in 12.5 seconds.
# Car 327 arriving at gas station at 52680
# Calling tank truck at 52690
# Car 327 finished refueling in 20.5 seconds.
# Car 328 arriving at gas station at 52945
# Tank truck arriving at time 52990
# Tank truck refuelling 173 liters.
# Car 328 finished refueling in 65.0 seconds.
# Car 329 arriving at gas station at 53197
# Car 329 finished refueling in 12.5 seconds.
# Car 330 arriving at gas station at 53494
# Car 330 finished refueling in 13.0 seconds.
# Car 331 arriving at gas station at 53662
# Car 331 finished refueling in 15.5 seconds.
# Car 332 arriving at gas station at 53939
# Car 332 finished refueling in 13.5 seconds.
# Car 333 arriving at gas station at 54192
# Calling tank truck at 54200
# Car 333 finished refueling in 17.5 seconds.
# Car 334 arriving at gas station at 54359
# Tank truck arriving at time 54500
# Tank truck refuelling 184 liters.
# Car 335 arriving at gas station at 54514
# Car 334 finished refueling in 162.5 seconds.
# Car 335 finished refueling in 15.5 seconds.
# Car 336 arriving at gas station at 54686
# Car 336 finished refueling in 15.5 seconds.
# Car 337 arriving at gas station at 54840
# Car 337 finished refueling in 17.5 seconds.
# Car 338 arriving at gas station at 55064
# Calling tank truck at 55070
# Car 338 finished refueling in 15.0 seconds.
# Car 339 arriving at gas station at 55108
# Car 340 arriving at gas station at 55304
# Tank truck arriving at time 55370
# Tank truck refuelling 170 liters.
# Car 340 finished refueling in 85.5 seconds.
# Car 339 finished refueling in 282.0 seconds.
# Car 341 arriving at gas station at 55583
# Car 341 finished refueling in 18.5 seconds.
# Car 342 arriving at gas station at 55794
# Car 342 finished refueling in 18.5 seconds.
# Car 343 arriving at gas station at 55998
# Calling tank truck at 56000
# Car 343 finished refueling in 14.0 seconds.
# Car 344 arriving at gas station at 56169
# Car 345 arriving at gas station at 56204
# Tank truck arriving at time 56300
# Tank truck refuelling 181 liters.
# Car 344 finished refueling in 145.5 seconds.
# Car 345 finished refueling in 117.5 seconds.
# Car 346 arriving at gas station at 56331
# Car 346 finished refueling in 16.0 seconds.
# Car 347 arriving at gas station at 56484
# Car 347 finished refueling in 14.0 seconds.
# Car 348 arriving at gas station at 56764
# Calling tank truck at 56770
# Car 348 finished refueling in 15.0 seconds.
# Car 349 arriving at gas station at 56917
# Car 349 finished refueling in 15.5 seconds.
# Tank truck arriving at time 57070
# Tank truck refuelling 193 liters.
# Car 350 arriving at gas station at 57198
# Car 350 finished refueling in 21.5 seconds.
# Car 351 arriving at gas station at 57236
# Car 351 finished refueling in 19.0 seconds.
# Car 352 arriving at gas station at 57416
# Car 352 finished refueling in 19.0 seconds.
# Car 353 arriving at gas station at 57653
# Car 353 finished refueling in 13.5 seconds.
# Car 354 arriving at gas station at 57839
# Calling tank truck at 57840
# Car 354 finished refueling in 15.0 seconds.
# Car 355 arriving at gas station at 58057
# Tank truck arriving at time 58140
# Tank truck refuelling 176 liters.
# Car 355 finished refueling in 99.0 seconds.
# Car 356 arriving at gas station at 58263
# Car 356 finished refueling in 17.0 seconds.
# Car 357 arriving at gas station at 58462
# Car 357 finished refueling in 18.5 seconds.
# Car 358 arriving at gas station at 58724
# Car 358 finished refueling in 18.5 seconds.
# Car 359 arriving at gas station at 58910
# Calling tank truck at 58920
# Car 359 finished refueling in 21.0 seconds.
# Car 360 arriving at gas station at 59058
# Car 361 arriving at gas station at 59186
# Tank truck arriving at time 59220
# Tank truck refuelling 182 liters.
# Car 361 finished refueling in 48.0 seconds.
# Car 360 finished refueling in 179.5 seconds.
# Car 362 arriving at gas station at 59277
# Car 362 finished refueling in 19.5 seconds.
# Car 363 arriving at gas station at 59401
# Car 363 finished refueling in 15.0 seconds.
# Car 364 arriving at gas station at 59541
# Car 364 finished refueling in 13.5 seconds.
# Car 365 arriving at gas station at 59712
# Calling tank truck at 59720
# Car 365 finished refueling in 13.0 seconds.
# Car 366 arriving at gas station at 60010
# Tank truck arriving at time 60020
# Tank truck refuelling 185 liters.
# Car 366 finished refueling in 31.0 seconds.
# Car 367 arriving at gas station at 60184
# Car 367 finished refueling in 18.0 seconds.
# Car 368 arriving at gas station at 60313
# Car 368 finished refueling in 17.0 seconds.
# Car 369 arriving at gas station at 60459
# Car 369 finished refueling in 18.0 seconds.
# Car 370 arriving at gas station at 60580
# Calling tank truck at 60590
# Car 370 finished refueling in 14.0 seconds.
# Car 371 arriving at gas station at 60617
# Car 372 arriving at gas station at 60711
# Car 373 arriving at gas station at 60764
# Tank truck arriving at time 60890
# Tank truck refuelling 176 liters.
# Car 371 finished refueling in 291.5 seconds.
# Car 372 finished refueling in 201.0 seconds.
# Car 373 finished refueling in 165.0 seconds.
# Car 374 arriving at gas station at 60943
# Calling tank truck at 60950
# Car 374 finished refueling in 21.0 seconds.
# Car 375 arriving at gas station at 61224
# Car 375 finished refueling in 13.5 seconds.
# Tank truck arriving at time 61250
# Tank truck refuelling 191 liters.
# Car 376 arriving at gas station at 61260
# Car 376 finished refueling in 15.0 seconds.
# Car 377 arriving at gas station at 61435
# Car 377 finished refueling in 15.5 seconds.
# Car 378 arriving at gas station at 61710
# Car 378 finished refueling in 20.0 seconds.
# Car 379 arriving at gas station at 61914
# Car 379 finished refueling in 18.5 seconds.
# Car 380 arriving at gas station at 61970
# Calling tank truck at 61980
# Car 380 finished refueling in 21.0 seconds.
# Car 381 arriving at gas station at 62244
# Tank truck arriving at time 62280
# Tank truck refuelling 180 liters.
# Car 381 finished refueling in 52.5 seconds.
# Car 382 arriving at gas station at 62307
# Car 382 finished refueling in 21.5 seconds.
# Car 383 arriving at gas station at 62588
# Car 383 finished refueling in 20.5 seconds.
# Car 384 arriving at gas station at 62645
# Car 384 finished refueling in 13.5 seconds.
# Car 385 arriving at gas station at 62751
# Calling tank truck at 62760
# Car 385 finished refueling in 21.5 seconds.
# Car 386 arriving at gas station at 62936
# Tank truck arriving at time 63060
# Tank truck refuelling 187 liters.
# Car 386 finished refueling in 145.0 seconds.
# Car 387 arriving at gas station at 63093
# Car 387 finished refueling in 13.0 seconds.
# Car 388 arriving at gas station at 63336
# Car 388 finished refueling in 14.5 seconds.
# Car 389 arriving at gas station at 63481
# Car 389 finished refueling in 15.5 seconds.
# Car 390 arriving at gas station at 63705
# Calling tank truck at 63710
# Car 390 finished refueling in 18.0 seconds.
# Car 391 arriving at gas station at 63961
# Car 391 finished refueling in 18.0 seconds.
# Tank truck arriving at time 64010
# Tank truck refuelling 200 liters.
# Car 392 arriving at gas station at 64210
# Car 392 finished refueling in 13.0 seconds.
# Car 393 arriving at gas station at 64270
# Car 393 finished refueling in 19.5 seconds.
# Car 394 arriving at gas station at 64350
# Car 394 finished refueling in 18.5 seconds.
# Car 395 arriving at gas station at 64488
# Car 395 finished refueling in 20.0 seconds.
# Car 396 arriving at gas station at 64559
# Calling tank truck at 64560
# Car 396 finished refueling in 20.0 seconds.
# Car 397 arriving at gas station at 64711
# Car 398 arriving at gas station at 64779
# Car 399 arriving at gas station at 64810
# Tank truck arriving at time 64860
# Tank truck refuelling 182 liters.
# Car 398 finished refueling in 97.0 seconds.
# Car 397 finished refueling in 169.0 seconds.
# Car 399 finished refueling in 79.0 seconds.
# Car 400 arriving at gas station at 65070
# Car 400 finished refueling in 18.0 seconds.
# Car 401 arriving at gas station at 65340
# Calling tank truck at 65350
# Car 401 finished refueling in 19.0 seconds.
# Car 402 arriving at gas station at 65386
# Car 403 arriving at gas station at 65563
# Tank truck arriving at time 65650
# Tank truck refuelling 172 liters.
# Car 402 finished refueling in 282.0 seconds.
# Car 403 finished refueling in 108.5 seconds.
# Car 404 arriving at gas station at 65825
# Car 404 finished refueling in 18.5 seconds.
# Car 405 arriving at gas station at 65974
# Car 405 finished refueling in 16.0 seconds.
# Car 406 arriving at gas station at 66105
# Calling tank truck at 66110
# Car 406 finished refueling in 14.0 seconds.
# Car 407 arriving at gas station at 66193
# Car 408 arriving at gas station at 66338
# Tank truck arriving at time 66410
# Tank truck refuelling 176 liters.
# Car 407 finished refueling in 229.5 seconds.
# Car 408 finished refueling in 90.5 seconds.
# Car 409 arriving at gas station at 66444
# Car 409 finished refueling in 21.5 seconds.
# Car 410 arriving at gas station at 66546
# Car 410 finished refueling in 20.0 seconds.
# Car 411 arriving at gas station at 66606
# Calling tank truck at 66610
# Car 411 finished refueling in 13.0 seconds.
# Car 412 arriving at gas station at 66793
# Tank truck arriving at time 66910
# Tank truck refuelling 171 liters.
# Car 412 finished refueling in 132.5 seconds.
# Car 413 arriving at gas station at 66970
# Car 413 finished refueling in 15.5 seconds.
# Car 414 arriving at gas station at 67063
# Car 414 finished refueling in 16.5 seconds.
# Car 415 arriving at gas station at 67248
# Car 415 finished refueling in 14.5 seconds.
# Car 416 arriving at gas station at 67417
# Car 416 finished refueling in 15.5 seconds.
# Car 417 arriving at gas station at 67699
# Calling tank truck at 67700
# Car 417 finished refueling in 13.0 seconds.
# Car 418 arriving at gas station at 67770
# Car 419 arriving at gas station at 67820
# Tank truck arriving at time 68000
# Tank truck refuelling 181 liters.
# Car 419 finished refueling in 193.0 seconds.
# Car 420 arriving at gas station at 68015
# Car 418 finished refueling in 246.0 seconds.
# Car 420 finished refueling in 22.5 seconds.
# Car 421 arriving at gas station at 68173
# Car 421 finished refueling in 19.0 seconds.
# Car 422 arriving at gas station at 68249
# Calling tank truck at 68250
# Car 422 finished refueling in 18.5 seconds.
# Car 423 arriving at gas station at 68289
# Car 424 arriving at gas station at 68339
# Tank truck arriving at time 68550
# Tank truck refuelling 178 liters.
# Car 424 finished refueling in 225.5 seconds.
# Car 423 finished refueling in 281.0 seconds.
# Car 425 arriving at gas station at 68609
# Car 425 finished refueling in 18.5 seconds.
# Car 426 arriving at gas station at 68865
# Car 426 finished refueling in 13.5 seconds.
# Car 427 arriving at gas station at 68987
# Car 427 finished refueling in 12.5 seconds.
# Car 428 arriving at gas station at 69240
# Car 429 arriving at gas station at 69521
# Car 430 arriving at gas station at 69791
# Car 431 arriving at gas station at 70030
# Car 432 arriving at gas station at 70224
# Car 433 arriving at gas station at 70336
# Car 434 arriving at gas station at 70576
# Car 435 arriving at gas station at 70753
# Car 436 arriving at gas station at 70801
# Car 437 arriving at gas station at 70876
# Car 438 arriving at gas station at 71035
# Car 439 arriving at gas station at 71124
# Car 440 arriving at gas station at 71417
# Car 441 arriving at gas station at 71683
# Car 442 arriving at gas station at 71740
# Car 443 arriving at gas station at 72035
# Car 444 arriving at gas station at 72320
# Car 445 arriving at gas station at 72576
# Car 446 arriving at gas station at 72710
# Car 447 arriving at gas station at 72807
# Car 448 arriving at gas station at 73061
# Car 449 arriving at gas station at 73153
# Car 450 arriving at gas station at 73305
# Car 451 arriving at gas station at 73494
# Car 452 arriving at gas station at 73531
# Car 453 arriving at gas station at 73769
# Car 454 arriving at gas station at 73914
# Car 455 arriving at gas station at 74180
# Car 456 arriving at gas station at 74288
# Car 457 arriving at gas station at 74467
# Car 458 arriving at gas station at 74636
# Car 459 arriving at gas station at 74913
# Car 460 arriving at gas station at 75067
# Car 461 arriving at gas station at 75171
# Car 462 arriving at gas station at 75298
# Car 463 arriving at gas station at 75588
# Car 464 arriving at gas station at 75653
# Car 465 arriving at gas station at 75895
# Car 466 arriving at gas station at 76184
# Car 467 arriving at gas station at 76215
# Car 468 arriving at gas station at 76397
# Car 469 arriving at gas station at 76677
# Car 470 arriving at gas station at 76935
# Car 471 arriving at gas station at 77212
# Car 472 arriving at gas station at 77412
# Car 473 arriving at gas station at 77635
# Car 474 arriving at gas station at 77829
# Car 475 arriving at gas station at 77981
# Car 476 arriving at gas station at 78207
# Car 477 arriving at gas station at 78447
# Car 478 arriving at gas station at 78639
# Car 479 arriving at gas station at 78864
# Car 480 arriving at gas station at 78971
# Car 481 arriving at gas station at 79019
# Car 482 arriving at gas station at 79306
# Car 483 arriving at gas station at 79505
# Car 484 arriving at gas station at 79760
# Car 485 arriving at gas station at 80059
# Car 486 arriving at gas station at 80096
# Car 487 arriving at gas station at 80335
# Car 488 arriving at gas station at 80444
# Car 489 arriving at gas station at 80714
# Car 490 arriving at gas station at 80917
# Car 491 arriving at gas station at 81150
# Car 492 arriving at gas station at 81221
# Car 493 arriving at gas station at 81445
# Car 494 arriving at gas station at 81724
# Car 495 arriving at gas station at 81772
# Car 496 arriving at gas station at 81837
# Car 497 arriving at gas station at 82014
# Car 498 arriving at gas station at 82090
# Car 499 arriving at gas station at 82170
# Car 500 arriving at gas station at 82251
# Car 501 arriving at gas station at 82366
# Car 502 arriving at gas station at 82410
# Car 503 arriving at gas station at 82606
# Car 504 arriving at gas station at 82786
# Car 505 arriving at gas station at 83007
# Car 506 arriving at gas station at 83111
# Car 507 arriving at gas station at 83351
# Car 508 arriving at gas station at 83473
# Car 509 arriving at gas station at 83592
# Car 510 arriving at gas station at 83817
# Car 511 arriving at gas station at 83970
# Car 512 arriving at gas station at 84073
# Car 513 arriving at gas station at 84339
# Car 514 arriving at gas station at 84499
# Car 515 arriving at gas station at 84659
# Car 516 arriving at gas station at 84927
# Car 517 arriving at gas station at 85037
# Car 518 arriving at gas station at 85293
# Car 519 arriving at gas station at 85476
# Car 520 arriving at gas station at 85723
# Car 521 arriving at gas station at 85986
# Car 522 arriving at gas station at 86117
# Car 523 arriving at gas station at 86394
# Car 524 arriving at gas station at 86545
# Car 525 arriving at gas station at 86758
# Car 526 arriving at gas station at 86939
# Car 527 arriving at gas station at 86980
# Car 528 arriving at gas station at 87150
# Car 529 arriving at gas station at 87205
# Car 530 arriving at gas station at 87489
# Car 531 arriving at gas station at 87636
# Car 532 arriving at gas station at 87846
# Car 533 arriving at gas station at 87973
# Car 534 arriving at gas station at 88131
# Car 535 arriving at gas station at 88210
# Car 536 arriving at gas station at 88260
# Car 537 arriving at gas station at 88515
# Car 538 arriving at gas station at 88731
# Car 539 arriving at gas station at 88807
# Car 540 arriving at gas station at 89004
# Car 541 arriving at gas station at 89123
# Car 542 arriving at gas station at 89220
# Car 543 arriving at gas station at 89437
# Car 544 arriving at gas station at 89723
# Car 545 arriving at gas station at 89837
# Car 546 arriving at gas station at 90113
# Car 547 arriving at gas station at 90316
# Car 548 arriving at gas station at 90585
# Car 549 arriving at gas station at 90687
# Car 550 arriving at gas station at 90920
# Car 551 arriving at gas station at 91137
# Car 552 arriving at gas station at 91369
# Car 553 arriving at gas station at 91534
# Car 554 arriving at gas station at 91627
# Car 555 arriving at gas station at 91845
# Car 556 arriving at gas station at 92070
# Car 557 arriving at gas station at 92290
# Car 558 arriving at gas station at 92439
# Car 559 arriving at gas station at 92481
# Car 560 arriving at gas station at 92678
# Car 561 arriving at gas station at 92821
# Car 562 arriving at gas station at 92883
# Car 563 arriving at gas station at 93150
# Car 564 arriving at gas station at 93389
# Car 565 arriving at gas station at 93490
# Car 566 arriving at gas station at 93539
# Car 567 arriving at gas station at 93821
# Car 568 arriving at gas station at 93900
# Car 569 arriving at gas station at 93999
# Car 570 arriving at gas station at 94261
# Car 571 arriving at gas station at 94505
# Car 572 arriving at gas station at 94614
# Car 573 arriving at gas station at 94694
# Car 574 arriving at gas station at 94932
# Car 575 arriving at gas station at 94978
# Car 576 arriving at gas station at 95119
# Car 577 arriving at gas station at 95376
# Car 578 arriving at gas station at 95591
# Car 579 arriving at gas station at 95809
# Car 580 arriving at gas station at 96022
# Car 581 arriving at gas station at 96255
# Car 582 arriving at gas station at 96382
# Car 583 arriving at gas station at 96644
# Car 584 arriving at gas station at 96782
# Car 585 arriving at gas station at 96822
# Car 586 arriving at gas station at 97022
# Car 587 arriving at gas station at 97116
# Car 588 arriving at gas station at 97251
# Car 589 arriving at gas station at 97387
# Car 590 arriving at gas station at 97527
# Car 591 arriving at gas station at 97725
# Car 592 arriving at gas station at 97756
# Car 593 arriving at gas station at 97860
# Car 594 arriving at gas station at 98018
# Car 595 arriving at gas station at 98104
# Car 596 arriving at gas station at 98201
# Car 597 arriving at gas station at 98414
# Car 598 arriving at gas station at 98609
# Car 599 arriving at gas station at 98728
# Car 600 arriving at gas station at 98784
# Car 601 arriving at gas station at 99029
# Car 602 arriving at gas station at 99117
# Car 603 arriving at gas station at 99390
# Car 604 arriving at gas station at 99605
# Car 605 arriving at gas station at 99690
# Car 606 arriving at gas station at 99977
